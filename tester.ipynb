# %% [markdown]
# <a href="https://colab.research.google.com/github/cogodo/EECS598-Final-Project/blob/main/tester.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://SHA256:Q+h3X7BvzwMgThHxuTG6jBAo5RKLdjQWyJBdVt2RFlE@github.com/josefbrozovich/RLHF_FM
# Out:
# Cloning into 'RLHF_FM'...
# remote: Invalid username or token. Password authentication is not supported for Git operations.
# fatal: Authentication failed for 'https://github.com/josefbrozovich/RLHF_FM/'

# %%
# !pip3 install numpy
